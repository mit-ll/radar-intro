# %%
import rad.toys as ts

# %%
ts.friis()

# %%
import rad.plot as plt
import numpy as np

# %%
f, a = plt.new_plot()
qm = a.contourf(np.arange(10), np.arange(10), np.random.randn(10, 10))

# %%
dir(qm)
# Out:
# ['_A',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_label',
#  '_algorithm',
#  '_autolev',
#  '_check_xyz',
#  '_contour_args',
#  '_contour_generator',
#  '_contour_zorder',
#  '_corner_mask',
#  '_extend_max',
#  '_extend_min',
#  '_get_allsegs_and_allkinds',
#  '_get_label_clabeltext',
#  '_get_label_text',
#  '_get_lowers_and_uppers',
#  '_get_nth_label_width',
#  '_id_norm',
#  '_initialize_x_y',
#  '_levels',
#  '_make_paths',
#  '_maxs',
#  '_mins',
#  '_norm',
#  '_process_args',
#  '_process_colors',
#  '_process_contour_level_args',
#  '_process_levels',
# ...
